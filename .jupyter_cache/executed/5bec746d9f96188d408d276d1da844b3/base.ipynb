.2039053, "/opt/anaconda3/lib/python3.13/ntpath.py": 1749746012.8657074, "/opt/anaconda3/lib/python3.13/warnings.py": 1749746013.2914565, "/opt/anaconda3/lib/python3.13/lib-dynload/grp.cpython-313-darwin.so": 1749746051.274073, "/opt/anaconda3/lib/python3.13/pathlib/_local.py": 1749746016.2104545, "/opt/anaconda3/lib/python3.13/pathlib/__init__.py": 1749746016.1975684, "/opt/anaconda3/lib/python3.13/typing.py": 1749746013.2795715, "/opt/anaconda3/lib/python3.13/site-packages/ipykernel/_version.py": 1737661180.2559798, "/opt/anaconda3/lib/python3.13/__future__.py": 1749746012.3546097, "/opt/anaconda3/lib/python3.13/lib-dynload/_json.cpython-313-darwin.so": 1749746059.4272153, "/opt/anaconda3/lib/python3.13/json/scanner.py": 1749746015.9632561, "/opt/anaconda3/lib/python3.13/json/decoder.py": 1749746015.9495623, "/opt/anaconda3/lib/python3.13/json/encoder.py": 1749746015.9564278, "/opt/anaconda3/lib/python3.13/json/__init__.py": 1749746015.9432712, "/opt/anaconda3/lib/python3.13/locale.py": 1749746012.8259294, "/opt/anaconda3/lib/python3.13/signal.py": 1749746013.084407, "/opt/anaconda3/lib/python3.13/_weakrefset. ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import fetch_openml

# Load Ames Housing dataset
ames = fetch_openml(name="house_prices", as_frame=True)
df = ames.frame.copy()

df.rename(columns={"SalePrice": "Sale_Price"}, inplace=True)

df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  Sale_Price
# 0   2008        WD         Normal      208500
# 1   2007        WD         Normal      181500
# 2   2008        WD         Normal      223500
# 3   2006        WD        Abnorml      140000
# 4   2008        WD         Normal      250000
#
# [5 rows x 81 columns]

# %%
predictors = [
    "Sale_Price",
    "BedroomAbvGr",
    "YearBuilt",
    "MoSold",
    "LotArea",
    "Street",
    "CentralAir",
    "1stFlrSF",
    "2ndFlrSF",
    "FullBath",
    "HalfBath",
    "Fireplaces",
    "GarageArea",
    "GrLivArea",
    "TotRmsAbvGrd"
]

df = df[predictors].dropna()

# %%
median_price = df["Sale_Price"].median()

df["Price_High"] = np.where(df["Sale_Price"] > median_price, "High", "Low")
df["Price_High"] = df["Price_High"].astype("category")

df["Price_High"].value_counts(normalize=True)
# Out:
# Price_High
# Low     0.50137
# High    0.49863
# Name: proportion, dtype: float64

# %%
X = df.drop(columns=["Sale_Price", "Price_High"])
y = df["Price_High"]

# Encode categorical predictors
X = pd.get_dummies(X, drop_first=True)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=4321, stratify=y
)

X_train.shape, X_test.shape
# Out:
# ((1022, 14), (438, 14))

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(X_test)

# Extract the probability of the TRUE positive class ("High")
pos_index = np.where(gnb.classes_ == "High")[0][0]
y_prob_high = gnb.predict_proba(X_test)[:, pos_index]

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[187,  31],
#        [ 20, 200]])

# %%
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         High       0.90      0.86      0.88       218
#          Low       0.87      0.91      0.89       220
#
#     accuracy                           0.88       438
#    macro avg       0.88      0.88      0.88       438
# weighted avg       0.88      0.88      0.88       438

# %%
# Convert y_test to binary (1 = High, 0 = Low)
y_test_binary = (y_test == "High").astype(int)

# Compute ROC using correct positive class probability
fpr, tpr, thresholds = roc_curve(y_test_binary, y_prob_high)
roc_auc = auc(fpr, tpr)

roc_auc
# Out:
# np.float64(0.9547122602168474)

# %%
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.3f}", linewidth=3)
plt.plot([0,1], [0,1], "k--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Naive Bayes (Corrected)")
plt.legend()
plt.show()
